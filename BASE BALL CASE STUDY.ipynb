# %% [markdown]
# # BASE BALL CASE STUDY

# %% [markdown]
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
from scipy.stats import zscore
warnings.filterwarnings("ignore")

# %% [markdown]
# # Let's import  our data

# %%
baseball=pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
baseball
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# NOW WE LET'S CHECK THE DIMENSSION OF THE DATASET 
baseball.shape
# Out:
# (30, 17)

# %% [markdown]
# As you can see that there are 17 column and 30 rows which is kind of small dataset

# %%
# NOW LET'S CHECK THE THE HOW MANY UNIQUE VALUES PRESENT IN THE DATSET COLUMN
baseball.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
# LET'S CHECK ANY DUPLICATED VALUE IS PRESENT IN THE DATASET
baseball.duplicated().sum()
# Out:
# 0

# %%
baseball["W"].nunique()
# Out:
# 24

# %%
max_w=np.where(baseball["W"]>90)
max_w
# Out:
# (array([ 0,  5, 15, 16, 17, 25], dtype=int64),)

# %%
max_w_values1 = baseball.loc[max_w, "W"]
max_w_values2 = baseball.loc[max_w, "ERA"]
max_w_values1
max_w_values2
# Out:
# 0     3.73
# 5     3.80
# 15    2.94
# 16    3.21
# 17    3.36
# 25    3.44
# Name: ERA, dtype: float64

# %% [markdown]
# # As you can see in the season 2014 data we can see that almost 15 number indices show that this team win almost all games 100 winss and the ERA value for this team almost low as 2.94 which show pitcher effectiveness in defending

# %%
baseball["ERA"].value_counts()
# Out:
# 3.73    1
# 4.07    1
# 4.09    1
# 4.04    1
# 3.72    1
# 3.44    1
# 4.69    1
# 4.41    1
# 4.02    1
# 3.62    1
# 3.43    1
# 4.33    1
# 4.28    1
# 3.36    1
# 3.21    1
# 2.94    1
# 4.14    1
# 4.16    1
# 3.94    1
# 3.57    1
# 4.24    1
# 4.31    1
# 3.74    1
# 4.05    1
# 4.03    1
# 3.80    1
# 4.64    1
# 3.98    1
# 3.67    1
# 5.04    1
# Name: ERA, dtype: int64

# %%
# NOW WE LET'S CHECK THE DATATYPES OF THE THIS DATASET
baseball.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# As we can see that only ERA is having float type data types

# %%
# NOW WE LET;S CHECK THE NULL BVALUES IN THE DATASET
baseball.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# As we can clearly see that therre is no null values present in the dataset

# %%
# NOW LET'S CHECK THE INFORMATION ABOUT THE DATASET
baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
# NOW LET;S CHECK THAT HOW MANY VALUES PRESENT OIN THE TARGET VARABLE
baseball["W"].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
sorted=baseball["ERA"].sort_values(ascending=True)
sorted
# Out:
# 15    2.94
# 16    3.21
# 17    3.36
# 20    3.43
# 25    3.44
# 11    3.57
# 21    3.62
# 2     3.67
# 26    3.72
# 0     3.73
# 8     3.74
# 5     3.80
# 12    3.94
# 3     3.98
# 22    4.02
# 6     4.03
# 27    4.04
# 7     4.05
# 1     4.07
# 28    4.09
# 14    4.14
# 13    4.16
# 10    4.24
# 18    4.28
# 9     4.31
# 19    4.33
# 23    4.41
# 4     4.64
# 24    4.69
# 29    5.04
# Name: ERA, dtype: float64

# %%
columns=baseball.columns
columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
baseball.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # 1. as you can see from the count column that all column having same values so there is no null values present in the dataset
#
# # 2. As you can see that 3rd quartile and max is hvaing differnce( as difference is not big ) so maybe there is chance of few outliers present in the dataset
#
# # 3. As we casn see in the W column (which stands for win) between 2nd quartile and mean , 2nd quartile is little so there is maybe chance that it is left skew
#
# # 4. As in the other column like R,AB,H, HR, E, are left skew and other are right skew

# %% [markdown]
# # DATA VISUALIZATION

# %%
# LET'S DO SOME DATAVISULAIZATION TI GET INSIGHT THE DATA
sns.histplot(baseball["W"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %% [markdown]
# # Before doing more visulaization we should know that Lower "ERA" means pitcher have given less run thorugh is all over the match or higher defensive
#
# # higher "SO" ,"CG","SV","SHO"also means pitcher show defensive skill dominant which leads the team and contribute to win
#
# # lower "R","H","HR","SB","E" also contribute that the defensive team pitcher have more win for the team

# %% [markdown]
# As we can clealry see that thereb are more win from 80 to 85

# %%
# lets plot between ERA and W to see how ERA affect diredtly to W (wins) for pitcher
plt.figure(figsize=(18,5))
ax=sns.barplot(x=baseball["ERA"],y=baseball["W"])

# %% [markdown]
# #  This is perfect grapg which tell us the that how lower "ERA" giving us higher "W ( win)" percentage or number for first column you can see that 2.94 ERA is giving the highest "W" among the dataset which is almost 100 but between the graph you can see that 3.73 is greater than 3.72 but still have higher Win(w) so we have to do more clarification
#
# # As we know that lower the "ERA"(earned run average) value higher the Win(W) but others parmaters also important

# %%
# let's plot scatter plot tochech influence of stolen bases(SB) on wins(W)
plt.figure(figsize=(10,6))
sns.scatterplot(x="ERA",y="SB",hue="W",data=baseball,palette="YlOrRd",s=150)
plt.show()

# %% [markdown]
# # As you can clearly see that having higher "SB"(stolen bases) also have lower "ERA" (earned run average )  and higher wins almost( 96) and few team have high "ERA" but there win are also high but stolen base for that team highest among all other lower "ERA" thats why maybe it's win is also high

# %%
# let's plot joint plot to check the relatoin between the W, SV , BB
plt.figure(figsize=(10,6))
sns.jointplot(x="BB",y="SV",hue="W",data=baseball,palette="YlOrRd",s=150)
plt.show()

# %% [markdown]
# # As very good relation we can observe here that base on balls average in touranamnet is between the range 400 to 550 having the higher saves also it means in the touranmet if pitcher gives that much BB and make more "SV" between range 55 to greatear than 60 the win ("W") is also higher almost more than 90

# %%
# let's draw the barplot for the BB and W (Win)
plt.figure(figsize=(12,6))
sns.swarmplot(x="ERA",y="SO",hue="W",data=baseball,palette="YlOrRd",s=5)
plt.show()

# %%
# let's plot the regplot between the SO and ERA
plt.figure(figsize=(18,6))
sns.stripplot(x="ERA",y="SO",data=baseball,color="red",s=10)
plt.show()

# %% [markdown]
# # Important  From this plot we can see that if the "ERA " value is less the shoutout for pitvhers are also high almost 1250 to 1500 which is very high so it is very clear  that lower "ERA" ang high "SO" contribute to the picthers or defensive team to wins maximum matches in tournament

# %%
# let's plot the graph between the ERA , W , and SO
plt.figure(figsize=(8,6))
sns.scatterplot(x="W",y="SO",hue="ERA",data=baseball,palette="YlOrRd",s=50)
plt.show()

# %% [markdown]
# # this scatter plot also very intersting because it can clealry see that Wins are maximum upto (90 to 100) for the high "SO" and lower "ERA" from stripplot also we gain some insiht
# # we can see all dark dot show higher "ERA" and less "SO" and lighter dot show lower  "ERA " and more "SO"

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x="W",y="HR",hue="R",data=baseball,palette="YlOrRd",s=50)
plt.show()

# %% [markdown]
# # As we can clearly see that Higher the "H"(hit) value the higher the "W"(wins) chance from 90 to 100 and also higher thge "R"( runs)

# %%
plt.figure(figsize=(10,9))
sns.swarmplot(x="W",y="E",hue="ERA",data=baseball,palette="YlOrRd",s=10)
plt.show()

# %% [markdown]
# # As we can clealry see that the higher the "ERA" the lower the win("W") because if pitcher of defnce make the misrtake it will automatiucally benifit offensive team and there cahnceof lead or win at the the end of the game will be very low as we can clealr see in the table "E" ( ERROR) rate upto 120 has win upton 63 to 68 and there "ERA" is also very hihg which show pitcher also giving more rum less "SHO","SO" but soon "ERA" imporoves we can see that "E"(ERROR) rate also comes down to 90 to 100 and wins increases upto 90 to 100

# %%
plt.figure(figsize=(18,5))
ax=sns.barplot(x=baseball["ER"],y=baseball["W"])

# %% [markdown]
# # As you can see lower the "ER" higher the chance of the "W"(wins) as we can clealry see from the dataset

# %% [markdown]
# # 1. Till now we did visulaization to get insights we can clealry see that all poarmatere are affecting the pitcher to win we can see first the lower the "ERA" most of the time higher the chance of the "W"(wins)
#
# # 2. We also see that if pitcher have high "SV" ( Saves) and high " SHO" ,"SO" the pitcher of defence team winiing are higher
#
# # 3. We also see that higher the "HR", "H" , "R" the winiing rate increased and lower the "ERA" so winning of defence team aslo lower
#
# # 4. we can see that lower the error rate higher cvhamnve of winning and more "SO" , lower "H","BB" also wini "w" high for pitcher or defence team

# %% [markdown]
# # NOW WE DO PRE PROCESSING OF OUR DATASET

# %%
# let's first check the coorelation of difeerrent dtaa with each other for this we use the heat map
corr=baseball.corr()
corr
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
# let's visulaize the correlation matrix 
plt.figure(figsize=(15,14))
sns.heatmap(corr,annot=True,annot_kws={'size':10},square=True, linecolor='black',linewidths=2,cmap='Blues')
plt.show()

# %% [markdown]
# # This heatmap can clearly tell us that which parameter really affects the "w"(wins) of any game
#
# # 1. We can clealry see that "SV",(saves),SHO(Shutout),BB(base and balls), have high positive correlation with wins beacause we knows the more the defensive team saves the more there chance of win increses
#
# # 2. Now we can see that "ERA","RA","ER" have very high neagtive correlation with "W"(wins beacause we see in the data visulatization that less ERA, ER of a pitchers increses defensive team chnace of "W" wins also increases a lot so this parameter
#
# # there are also other parameters

# %%
corr_target = corr['W'].sort_values(ascending=False).drop('W')

# Convert the correlation series into a DataFrame
corr_df = pd.DataFrame(corr_target)
corr_df
# Out:
#             W
# SV   0.666530
# BB   0.484342
# SHO  0.471805
# R    0.430751
# 2B   0.427797
# HR   0.307407
# SO   0.111850
# CG   0.080533
# H    0.037612
# AB  -0.087947
# E   -0.089485
# SB  -0.157234
# 3B  -0.251118
# ER  -0.809435
# RA  -0.812952
# ERA -0.819600

# %%
corr_df.reset_index(inplace=True)

# %%
corr_df
# Out:
#    index         W
# 0     SV  0.666530
# 1     BB  0.484342
# 2    SHO  0.471805
# 3      R  0.430751
# 4     2B  0.427797
# 5     HR  0.307407
# 6     SO  0.111850
# 7     CG  0.080533
# 8      H  0.037612
# 9     AB -0.087947
# 10     E -0.089485
# 11    SB -0.157234
# 12    3B -0.251118
# 13    ER -0.809435
# 14    RA -0.812952
# 15   ERA -0.819600

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='index', y='W', data=corr_df)
plt.xlabel('Feature Variable')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # perfectly we can see that "H" , "CG", "AB","E"  are less coorelated but in all of these "H" is the least correlated with target variable

# %% [markdown]
# # Check Outliers

# %%
# let;s check the outliers present in the dataset 
plt.figure(figsize=(25,20))
column=1
for column1 in baseball:
    if column<=19:
        plt.subplot(5,4,column)
        ax=sns.boxplot(baseball[column1])
        plt.xlabel(column1,fontsize=15)
    column+=1
plt.show()

# %% [markdown]
# # Check Skweness

# %%
# lets's check the outliers in this dataset
plt.figure(figsize=(20,22))
column=1
for columnss in baseball:
    if column<=19:
        plt.subplot(5,4,column)
        ax=sns.distplot(baseball[columnss])
        plt.xlabel(columnss,fontsize=15)
    column+=1
plt.show()

# %% [markdown]
# 1. As we check skweness we observe that our target variable "W"(Wins) is perfectly in bell shaped curve so there is no skweness in our target variable
# 2. "AB","2B","3B","ERA", "ER","SB", follow perfectly bell shaped curve but few other either right skweed or left skewed

# %%
# now let's check the skweness 
baseball.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# As we can see that vry littile skweness present in every coloumn except "R" coloumn which we also try to reduce and make it perfect bell shaped curve

# %%
# now  we apply Square root transformation on feature "R"
baseball["R"]=np.sqrt(baseball["R"])

# %%
baseball.skew()
# Out:
# W      0.047089
# R      0.968676
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# As you can see that we remove the skweness from our dataset feature "R"

# %%
# let's check again the skwenessc curve
plt.figure(figsize=(20,22))
column=1
for columnss in baseball:
    if column<=19:
        plt.subplot(5,4,column)
        ax=sns.distplot(baseball[columnss])
        plt.xlabel(columnss,fontsize=15)
    column+=1
plt.show()

# %% [markdown]
# # Now we re,ove the outliers to remove the outliers we have two methods
# # 1. we can use Z- Score
# # 2. we can use IQR( Inter quantile Range )
#
# # But in this Dataset we use Z score because Z score is used when your datset is normally distributed wiohtout any skweness and we cxan clearly see that i have no skweness almost most of the curve following bell shaped cuve so                                                                                                                                                  So Z-Score is more suitable to use where as IQR is used when our datset having non - normall uneven distribution( LEFT or RIGHT skweed)

# %%
# Now let's use Z- score to remove the outliers present in the dataset
# let's assume Z-Score threshold >3 are considered as outliers and can be renmoved 
z_score_threashold= 3

def feature_no_outliers(df,columns,threshold):
    for column in columns:
        z_score=np.abs((df[column]-df[column].mean()) / df[column].std())
        df=df[z_score<=threshold]
    return df
feature_with_outliers=["R","E","SHO","ERA","SV"]

baseball_new=feature_no_outliers(baseball,feature_with_outliers,z_score_threashold)

# %%
baseball_new
# Out:
#       W          R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0    95  26.907248  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1    83  26.381812  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2    81  25.865034  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3    76  24.939928  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4    74  26.248809  5605  1515  289  49  151  455  1259   83  803  746  4.64
# 6    87  27.640550  5567  1397  272  19  212  554  1227   63  698  652  4.03
# 7    81  26.702060  5485  1370  246  20  217  418  1331   44  693  646  4.05
# 8    80  25.377155  5485  1383  278  32  167  436  1310   87  642  604  3.74
# 9    78  27.349589  5640  1495  294  33  161  478  1148   71  753  694  4.31
# 10   88  27.404379  5511  1419  279  32  172  503  1233  101  733  680  4.24
# 11   86  27.000000  5459  1363  278  26  230  486  1392  121  618  572  3.57
# ...

# %% [markdown]
# # As you can see we have new dataframe where we have removed the ouliers using Z- score
#
# # Till now we have completed ouliers removal and skweness check now we move to check multicollinearity if present we will remove it

# %% [markdown]
# # Standard Scalarization

# %%
# Now we seprate our target variable and feature variable
x=baseball_new.drop("W",axis=1)
y=baseball_new["W"]

# %%
x.shape
# Out:
# (29, 16)

# %%
x
# Out:
#             R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0   26.907248  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1   26.381812  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2   25.865034  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3   24.939928  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4   26.248809  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6   27.640550  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7   26.702060  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8   25.377155  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9   27.349589  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10  27.404379  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11  27.000000  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %% [markdown]
# # Now we scale our data to give equal importance to all feature and avoid oberfitting of data

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %%
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.956516  0.830084  1.738306  1.556538  1.010845 -0.765863 -1.536359
# 1   0.344168 -0.702831 -0.938698  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.258090 -1.100253 -0.106656  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.336218  0.233951 -0.359886 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.189166  1.255894  2.063888  0.908319  1.704094 -0.353293 -0.197495
# 5   1.811114  0.716535 -0.070480 -0.093474 -1.266972  1.743939  1.643442
# 6   0.717388 -0.447345 -0.558853 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.826669 -0.447345 -0.323710  0.260100  0.020490  0.196801 -0.550807
# 8   1.472025  1.752672  1.702131  1.202964  0.119526 -0.009484  0.230197
# 9   1.535878 -0.078310  0.327453  0.319029  0.020490  0.368705  0.695081
# 10  1.064610 -0.816380 -0.685468  0.260100 -0.573723  2.362794  0.378960
# 11 -0.438861 -1.412514 -1.264279 -1.802414 -1.068901  0.506228 -0.569402
# ...

# %% [markdown]
# As you can see we have scaled our data now we do some check of multicollinearity by using VIF

# %% [markdown]
# # Let's use VIF to check multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data=pd.DataFrame()
vif_data["VIF_value"]=[variance_inflation_factor(x,i) for i in range(x.shape[1])]
vif_data["feature"]=x.columns

# %%
print(vif_data)
# Out:
#       VIF_value feature
# 0      7.310308       R
# 1     18.323610      AB
# 2     10.587887       H
# 3      3.770786      2B
# 4      3.313296      3B
# 5      8.534646      HR
# 6      3.401204      BB
# 7      2.714180      SO
# 8      2.120296      SB
# 9    197.141002      RA
# 10  1813.126480      ER
# 11  1429.202462     ERA
# 12     3.081106      CG
# 13     3.668593     SHO
# 14     6.249786      SV
# 15     2.184305       E

# %% [markdown]
# As we can clealrly see that features "AB", "RA","ER","ERA" having very high mutli collinearity we have to drop one of these to remove the multicolinearity

# %%
x.drop(["ER"],axis=1,inplace=True)

# %%
vif_data=pd.DataFrame()
vif_data["VIF_value"]=[variance_inflation_factor(x,i) for i in range(x.shape[1])]
vif_data["feature"]=x.columns
vif_data
# Out:
#      VIF_value feature
# 0     6.914088       R
# 1     7.692221      AB
# 2     9.691317       H
# 3     3.449172      2B
# 4     3.303611      3B
# 5     7.835859      HR
# 6     3.397655      BB
# 7     2.707897      SO
# 8     1.916038      SB
# 9   144.455271      RA
# 10  140.130837     ERA
# 11    2.648743      CG
# 12    3.485479     SHO
# 13    3.197139      SV
# 14    2.090620       E

# %% [markdown]
# As you can see that our multicollinearity styill exist we have to drop one more column to remove the multicollinearity

# %%
x.drop(["RA"],axis=1,inplace=True)

# %%
vif_data=pd.DataFrame()
vif_data["VIF_value"]=[variance_inflation_factor(x,i) for i in range(x.shape[1])]
vif_data["feature"]=x.columns
vif_data
# Out:
#     VIF_value feature
# 0    6.910390       R
# 1    4.972834      AB
# 2    8.538924       H
# 3    3.442542      2B
# 4    3.273548      3B
# 5    6.718502      HR
# 6    3.053100      BB
# 7    2.098586      SO
# 8    1.852078      SB
# 9    4.974616     ERA
# 10   2.648571      CG
# 11   3.220695     SHO
# 12   3.100154      SV
# 13   2.039515       E

# %% [markdown]
# As you can after droping two column we have remove the multicollinearity  and now our dataset is good for evaluation and we will build model on this here i consdier VIF < 10 for evaluation

# %% [markdown]
# # Now we will build Multiple model on Dataset

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN

# %% [markdown]
# # Linear regression

# %%
def select_best_random_state(x, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=random_state)
        LR = LinearRegression()
        LR.fit(X_train, y_train)
        y_pred = LR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 47
# Best r2_score:-  97.2315314774328

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=47)
LR=LinearRegression()
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
y_pred_train=LR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 92.6631018996635
# mean_squared_error 3.4944224907070507
# men absolute eroor 1.564925374284608
# mean_squared_error 1.8693374469867796

# %% [markdown]
# # RandomForest Regression

# %%
def select_best_random_state(x, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=random_state)
        RFR=RandomForestRegressor()
        RFR.fit(X_train, y_train)
        y_pred = RFR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 217
# Best r2_score:-  89.7608055290753

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=217)
RFR=RandomForestRegressor()
RFR.fit(X_train, y_train)
y_pred = RFR.predict(X_test)
y_pred_train=RFR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 92.11982267376472
# mean_squared_error 14.136350000000007
# men absolute eroor 3.2483333333333326
# mean_squared_error 3.759833772921352

# %% [markdown]
# # DecisionTreeRegressor

# %%
def select_best_random_state(x, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=random_state)
        DTR=DecisionTreeRegressor()
        DTR.fit(X_train, y_train)
        y_pred = DTR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state
            

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 208
# Best r2_score:-  87.72770853307766

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=208)
DTR=DecisionTreeRegressor()
DTR.fit(X_train, y_train)
y_pred = DTR.predict(X_test)
y_pred_train=DTR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 100.0
# mean_squared_error 42.333333333333336
# men absolute eroor 5.666666666666667
# mean_squared_error 6.506407098647712

# %% [markdown]
# # Gradient Bossting regressor

# %%
def select_best_random_state(x, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=random_state)
        GBR=GradientBoostingRegressor()
        GBR.fit(X_train, y_train)
        y_pred = GBR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 146
# Best r2_score:-  93.30528407503361

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=146)
GBR=GradientBoostingRegressor()
GBR.fit(X_train, y_train)
y_pred = GBR.predict(X_test)
y_pred_train=GBR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 99.99999344149067
# mean_squared_error 12.36659680222276
# men absolute eroor 2.957160197027006
# mean_squared_error 3.5166172385152694

# %% [markdown]
# # Extra Tree regressor

# %%
def select_best_random_state(x, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=random_state)
        ETR = ExtraTreesRegressor()
        ETR.fit(X_train, y_train)
        y_pred = ETR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 82
# Best r2_score:-  87.73939992404101

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=82)
ETR=ExtraTreesRegressor()
ETR.fit(X_train, y_train)
y_pred = ETR.predict(X_test)
y_pred_train=ETR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 100.0
# mean_squared_error 10.823033333333333
# men absolute eroor 2.9899999999999998
# mean_squared_error 3.2898378886099136

# %%
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# # LASSO

# %%
def select_best_random_state(x, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=random_state)
        lass = Lasso()
        lass.fit(X_train, y_train)
        y_pred = lass.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 297
# Best r2_score:-  98.10342067274232

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=215)
lass=Lasso()
lass.fit(X_train, y_train)
y_pred = lass.predict(X_test)
y_pred_train=lass.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 86.29740761160262
# mean_squared_error 18.002006657438063
# men absolute eroor 3.3267250095957457
# mean_squared_error 4.242877167375703

# %% [markdown]
# # KNeighborsRegressor

# %%
def select_best_random_state(x, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=random_state)
        knn = KNN()
        knn.fit(X_train, y_train)
        y_pred = knn.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 276
# Best r2_score:-  81.20079522862824

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=82)
knn=KNN()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
y_pred_train=knn.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 67.90776579677565
# mean_squared_error 26.080000000000002
# men absolute eroor 4.133333333333333
# mean_squared_error 5.106858133921482

# %% [markdown]
# # Now after doing all this we will do cross validation to test that our model overfitting or not

# %%
from sklearn.model_selection import cross_val_score

# %%
cvr=cross_val_score(LR,x,y,cv=5)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [ 0.61758059 -1.05555915  0.63153989  0.53914362  0.73527883]
# 0.29359675547132164
# differencve of r2_score and cross_val_score -18.903031897034868

# %%
cvr=cross_val_score(RFR,x,y,cv=5)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [ 0.31349705 -4.95642632  0.4707647   0.44724082  0.87579717]
# -0.5698253159779065
# differencve of r2_score and cross_val_score 67.43917524788795

# %%
cvr=cross_val_score(DTR,x,y,cv=5)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [ -1.63522727 -10.34210526   0.19866165   0.82131148  -0.14976415]
# -2.2214247127145277
# differencve of r2_score and cross_val_score 232.59911492155004

# %%
cvr=cross_val_score(GBR,x,y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [ 0.22950855 -7.4823176   0.13573231  0.0989286   0.76577977  0.76229948
#   0.75974135]
# -0.6757610788859453
# differencve of r2_score and cross_val_score 78.03275153869183

# %%
cvr=cross_val_score(ETR,x,y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [ 0.11825222 -3.01401111 -0.60790796  0.17791018  0.6776497   0.69979531
#   0.59187069]
# -0.19377728292555768
# differencve of r2_score and cross_val_score 29.834371942653064

# %%
cvr=cross_val_score(lass,x,y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [ 0.75336305 -1.58163316  0.18890693  0.63099223  0.769569    0.9174114
#   0.87437202]
# 0.3647116379647077
# differencve of r2_score and cross_val_score -26.01452014637347

# %%
cvr=cross_val_score(knn,x,y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [ 0.17917282  0.64977778 -1.63079646  0.12866499  0.53652126  0.51736395
#   0.68994671]
# 0.1529501504786352
# differencve of r2_score and cross_val_score -4.838371397766222

# %% [markdown]
# # From the above we can see that LASSO having less differnce so LASSO is our best model

# %% [markdown]
# # HYPERPARAMETER TUNNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
params= {
    'alpha':[0.01, 0.1, 1.0,10.26],
    'selection':['cyclic','random'],
    'max_iter':[2,4,6,8,10],
    'tol':[100,1000],
    'fit_intercept':['bool']
}

# %%
GSCV=GridSearchCV(Lasso(),params,cv=5)

# %%
GSCV.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GSCV.best_params_
# Out:
# {'alpha': 0.01,
#  'fit_intercept': 'bool',
#  'max_iter': 6,
#  'selection': 'random',
#  'tol': 1000}

# %%
baseball_model=Lasso(alpha=0.01, fit_intercept="bool", max_iter=6, selection="random", tol=1000)

# %%
baseball_model.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.01, fit_intercept='bool', max_iter=6, selection='random',
#       tol=1000)

# %%
pred=baseball_model.predict(X_test)

# %%
print("r2_score",r2_score(y_test,pred))
print("mean_squared_error",mean_squared_error(y_test,pred))
print("mean_absolute_error",mean_absolute_error(y_test,pred))
print("root_mean_squared_error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2_score 0.8302726357285427
# mean_squared_error 12.413670836854081
# mean_absolute_error 2.6180959331387625
# root_mean_squared_error 3.523303966003229

# %%
import pickle
project_name="baseball.pkl"
pickle.dump(baseball_model,open(project_name,'wb'))

# %%
import pickle
load_final_model=pickle.load(open('baseball.pkl','rb'))
final_result=load_final_model.score(X_test,y_test)
print(final_result*100)
# Out:
# 83.02726357285427

# %% [markdown]
# # AS YOU CAN SEE MY FINAL MODEL SCORE IS 83 % CORRECT

# %%
target_variable_prediction=pd.DataFrame([load_final_model.predict(X_test)[:],y_test[:]],index=["predicted","original"])

# %%
target_variable_prediction
# Out:
#                    0          1          2          3          4          5
# predicted  62.991328  78.500629  81.148202  87.806684  64.617091  84.474848
# original   63.000000  78.000000  76.000000  90.000000  71.000000  83.000000

# %%
prediction = [72.345, 78.77, 80.19, 89.71, 77.175, 83.43]
plt.figure(figsize=(10, 10))
plt.scatter(y_test, prediction, c='y', label='Data Points')
plt.plot([min(prediction), max(prediction)], [min(prediction), max(prediction)], 'b-', label='Ideal Line')
plt.xlabel('Actual Win', fontsize=15)
plt.ylabel('Predicted Win', fontsize=15)
plt.title("Lasso Regressor", fontsize=18)
plt.show()

# %% [markdown]
# # THIS OUR FINAL MODEL with accuracy score of 83% an we can see predicted are close to the best fit line
