# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # let's import our dataset

# %%
student=pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv")
student
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119 ME-107 CS-107 HS-205/20 MT-222 EE-222 MT-224 CS-210 CS-211 CS-203  \
# ...

# %%
student["CGPA"].max()
# Out:
# 3.985

# %%
student.iloc[0].value_counts()
# Out:
# C-          13
# C            5
# D+           4
# D            4
# B-           3
# A-           3
# C+           3
# B+           2
# A            2
# B            2
# CS-97001     1
# 2.205        1
# Name: 0, dtype: int64

# %%
student.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
for column in student.columns:
    filtered_data = student[student[column].str.contains('I', na=False)]
    print("Column:", column)
    print(filtered_data)
    
    print("\n")
# Out:
# Column: Seat No.
# Empty DataFrame
# Columns: [Seat No., PH-121, HS-101, CY-105, HS-105/12, MT-111, CS-105, CS-106, EL-102, EE-119, ME-107, CS-107, HS-205/20, MT-222, EE-222, MT-224, CS-210, CS-211, CS-203, CS-214, EE-217, CS-212, CS-215, MT-331, EF-303, HS-304, CS-301, CS-302, TC-383, MT-442, EL-332, CS-318, CS-306, CS-312, CS-317, CS-403, CS-421, CS-406, CS-414, CS-419, CS-423, CS-412, CGPA]
# Index: []
#
#
# Column: PH-121
# Empty DataFrame
# Columns: [Seat No., PH-121, HS-101, CY-105, HS-105/12, MT-111, CS-105, CS-106, EL-102, EE-119, ME-107, CS-107, HS-205/20, MT-222, EE-222, MT-224, CS-210, CS-211, CS-203, CS-214, EE-217, CS-212, CS-215, MT-331, EF-303, HS-304, CS-301, CS-302, TC-383, MT-442, EL-332, CS-318, CS-306, CS-312, CS-317, CS-403, CS-421, CS-406, CS-414, CS-419, CS-423, CS-412, CGPA]
# Index: []
#
#
# Column: HS-101
# Empty DataFrame
# ...

# %%
student.shape[1]
# Out:
# 43

# %% [markdown]
# As there 43 columns inside the dataset

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
student.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
student["CGPA"].value_counts()
# Out:
# 3.019    5
# 3.058    3
# 2.793    3
# 3.443    3
# 2.206    3
#         ..
# 2.555    1
# 2.042    1
# 2.634    1
# 2.053    1
# 1.753    1
# Name: CGPA, Length: 491, dtype: int64

# %%
rows_having_null = student[student.isnull().any(axis=1)]
pd.set_option('display.max_columns', None)
print(rows_having_null)
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 44   CS-97045      D      C    NaN       NaN    NaN     C-    NaN    NaN
# 60   CS-97061      C     B+     WU        D+     C-     B-      F      D
# 86   CS-97087      D      D     D+        B-      F      D      D      D
# 91   CS-97092     WU     C-      D         D     WU      D      D      D
# 137  CS-97138     C-     C+     WU        WU     WU      B     WU     WU
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 423  CS-97424      D     D+      D         D     C-      C     C+     B-
# 424  CS-97425     C-     D+     B-        C+     D+     C-     A-     C-
# 481  CS-97482     B-     A-     C+         D      B      B     A-     A-
# 543  CS-97544      A      B      A        A-     A-      A     B+     B+
# 565  CS-97566      F      F      D        C-    NaN     D+      D    NaN
#
#     EE-119 ME-107 CS-107 HS-205/20 MT-222 EE-222 MT-224 CS-210 CS-211 CS-203  \
# ...

# %% [markdown]
# if we see there are many null values present in the dataset in every column few column havew very less and few have very high null valyues present so we wil fill high null values column with mode and total 154 rows having null valuyes present

# %%
student_filled = rows_having_null.fillna(student.mode().iloc[0])
pd.set_option('display.max_columns', None)

# %%
print(student_filled)
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 44   CS-97045      D      C      A         A     A-     C-     A-     A-
# 60   CS-97061      C     B+     WU        D+     C-     B-      F      D
# 86   CS-97087      D      D     D+        B-      F      D      D      D
# 91   CS-97092     WU     C-      D         D     WU      D      D      D
# 137  CS-97138     C-     C+     WU        WU     WU      B     WU     WU
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 423  CS-97424      D     D+      D         D     C-      C     C+     B-
# 424  CS-97425     C-     D+     B-        C+     D+     C-     A-     C-
# 481  CS-97482     B-     A-     C+         D      B      B     A-     A-
# 543  CS-97544      A      B      A        A-     A-      A     B+     B+
# 565  CS-97566      F      F      D        C-     A-     D+      D     A-
#
#     EE-119 ME-107 CS-107 HS-205/20 MT-222 EE-222 MT-224 CS-210 CS-211 CS-203  \
# ...

# %% [markdown]
# As you can see all the null values in 154 rows are filled with mode data because data is categorical and we didn't drop the rows of null values because every rows is important because it indicated the the student so every student important

# %%
student.update(student_filled)

# %%
student
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119 ME-107 CS-107 HS-205/20 MT-222 EE-222 MT-224 CS-210 CS-211 CS-203  \
# ...

# %%
# let's check is there any null values present in the dataste or not
student.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [markdown]
# As we can clearly see that there is no null values present in the dataset good let's move on check other things

# %%
student.nunique()
# Out:
# Seat No.     571
# PH-121        13
# HS-101        12
# CY-105        13
# HS-105/12     13
# MT-111        13
# CS-105        11
# CS-106        13
# EL-102        13
# EE-119        12
# ME-107        13
# CS-107        14
# HS-205/20     13
# MT-222        14
# EE-222        13
# MT-224        14
# CS-210        14
# CS-211        14
# CS-203        13
# CS-214        13
# EE-217        13
# CS-212        12
# CS-215        14
# MT-331        12
# EF-303        12
# HS-304        14
# CS-301        12
# CS-302        11
# TC-383        12
# MT-442        12
# EL-332        13
# CS-318        14
# CS-306        13
# CS-312        14
# CS-317        12
# CS-403        11
# CS-421        13
# CS-406        14
# CS-414        13
# CS-419        12
# CS-423        12
# CS-412        13
# CGPA         491
# dtype: int64

# %%
student["PH-121"].value_counts()
# Out:
# A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64

# %%
student["MT-222"].value_counts()
# Out:
# A-    91
# A     80
# D     66
# B     61
# B-    52
# D+    46
# C     43
# B+    42
# C+    39
# C-    30
# A+    16
# F      3
# WU     1
# W      1
# Name: MT-222, dtype: int64

# %%
student["MT-331"].value_counts()
# Out:
# A     127
# A-    103
# B+     64
# B      57
# B-     46
# C-     32
# D+     31
# A+     30
# C      28
# C+     27
# D      22
# F       4
# Name: MT-331, dtype: int64

# %%
student.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %% [markdown]
# As we know that all are categorical variable

# %%
student=student.replace({'A+' : 4.0, 'A' : 3.8, 'A-' : 3.5, 'B+' : 3.3, 'B' : 3.0, 'B-' : 2.7, 'C+' : 2.4, 'C' : 2.0, 'C-' : 1.7, 'D+' : 1.4, 'D' : 1.0,'WU':0.5,'F':0.0,'W':0.2,'I':0.1})

# %%
student
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0    CS-97001     2.7     1.4     1.7        2.0     1.7     1.4     1.0
# 1    CS-97002     3.8     1.0     1.4        1.0     2.7     2.0     1.0
# 2    CS-97003     3.8     3.0     3.8        2.7     3.3     3.8     2.7
# 3    CS-97004     1.0     2.4     1.4        1.0     1.0     3.5     1.4
# 4    CS-97005     3.5     3.5     3.5        3.3     3.8     3.8     3.5
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566  CS-97567     3.0     3.8     3.8        3.5     4.0     3.8     3.5
# 567  CS-97568     4.0     3.8     3.8        3.8     3.8     3.8     3.8
# 568  CS-97569     3.0     3.8     3.5        3.3     3.8     3.8     3.8
# 569  CS-97570     3.8     3.3     1.0        3.8     1.0     1.4     2.7
# 570  CS-97571     2.0     1.0     1.0        2.0     2.0     1.4     3.0
#
#      EL-102  EE-119  ME-107  CS-107  HS-205/20  MT-222  EE-222  MT-224  \
# ...

# %%
# let's drop the unnessecary column from the dataset
student.drop(columns="Seat No.",inplace=True)

# %%
student
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0       2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7
# 1       3.8     1.0     1.4        1.0     2.7     2.0     1.0     3.8
# 2       3.8     3.0     3.8        2.7     3.3     3.8     2.7     3.3
# 3       1.0     2.4     1.4        1.0     1.0     3.5     1.4     1.7
# 4       3.5     3.5     3.5        3.3     3.8     3.8     3.5     3.3
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566     3.0     3.8     3.8        3.5     4.0     3.8     3.5     3.5
# 567     4.0     3.8     3.8        3.8     3.8     3.8     3.8     3.5
# 568     3.0     3.8     3.5        3.3     3.8     3.8     3.8     3.8
# 569     3.8     3.3     1.0        3.8     1.0     1.4     2.7     1.7
# 570     2.0     1.0     1.0        2.0     2.0     1.4     3.0     2.4
#
#      EE-119  ME-107  CS-107  HS-205/20  MT-222  EE-222  MT-224  CS-210  \
# ...

# %%
year_1=student.loc[ : ,"PH-121":"CS-107"]
year_1
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0       2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7
# 1       3.8     1.0     1.4        1.0     2.7     2.0     1.0     3.8
# 2       3.8     3.0     3.8        2.7     3.3     3.8     2.7     3.3
# 3       1.0     2.4     1.4        1.0     1.0     3.5     1.4     1.7
# 4       3.5     3.5     3.5        3.3     3.8     3.8     3.5     3.3
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566     3.0     3.8     3.8        3.5     4.0     3.8     3.5     3.5
# 567     4.0     3.8     3.8        3.8     3.8     3.8     3.8     3.5
# 568     3.0     3.8     3.5        3.3     3.8     3.8     3.8     3.8
# 569     3.8     3.3     1.0        3.8     1.0     1.4     2.7     1.7
# 570     2.0     1.0     1.0        2.0     2.0     1.4     3.0     2.4
#
#      EE-119  ME-107  CS-107
# 0       2.7     1.7     1.7
# 1       1.4     1.0     3.3
# ...

# %%
column_1=year_1.columns
column_1
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107'],
#       dtype='object')

# %%
year_1["CGPA"]=student["CGPA"]
year_1
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0       2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7
# 1       3.8     1.0     1.4        1.0     2.7     2.0     1.0     3.8
# 2       3.8     3.0     3.8        2.7     3.3     3.8     2.7     3.3
# 3       1.0     2.4     1.4        1.0     1.0     3.5     1.4     1.7
# 4       3.5     3.5     3.5        3.3     3.8     3.8     3.5     3.3
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566     3.0     3.8     3.8        3.5     4.0     3.8     3.5     3.5
# 567     4.0     3.8     3.8        3.8     3.8     3.8     3.8     3.5
# 568     3.0     3.8     3.5        3.3     3.8     3.8     3.8     3.8
# 569     3.8     3.3     1.0        3.8     1.0     1.4     2.7     1.7
# 570     2.0     1.0     1.0        2.0     2.0     1.4     3.0     2.4
#
#      EE-119  ME-107  CS-107   CGPA
# 0       2.7     1.7     1.7  2.205
# 1       1.4     1.0     3.3  2.008
# ...

# %%
year_2=student.loc[:,"HS-205/20":"CS-215"]
year_2
# Out:
#      HS-205/20  MT-222  EE-222  MT-224  CS-210  CS-211  CS-203  CS-214  \
# 0          3.3     1.0     3.5     2.7     2.4     1.4     1.4     1.0
# 1          2.4     2.7     1.7     1.4     1.4     1.0     2.0     1.0
# 2          3.5     3.8     3.8     3.8     3.8     4.0     3.8     3.5
# 3          3.0     1.4     2.7     1.0     2.0     3.3     2.4     1.0
# 4          3.8     3.8     3.5     3.5     3.5     2.7     3.8     3.5
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 566        3.8     4.0     3.8     3.8     3.8     3.8     4.0     3.8
# 567        3.3     2.4     3.5     3.0     3.8     3.8     4.0     4.0
# 568        2.7     3.0     3.3     3.0     3.5     3.8     3.3     3.0
# 569        2.4     1.0     1.0     3.0     2.7     3.0     2.7     2.0
# 570        2.4     1.7     3.3     1.4     3.3     1.7     3.0     1.4
#
#      EE-217  CS-212  CS-215
# 0       3.8     1.0     1.7
# 1       2.7     2.0     1.0
# ...

# %%
column_2=year_2.columns
column_2
# Out:
# Index(['HS-205/20', 'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203',
#        'CS-214', 'EE-217', 'CS-212', 'CS-215'],
#       dtype='object')

# %%
year_2["CGPA"]=student["CGPA"]
year_2
# Out:
#      HS-205/20  MT-222  EE-222  MT-224  CS-210  CS-211  CS-203  CS-214  \
# 0          3.3     1.0     3.5     2.7     2.4     1.4     1.4     1.0
# 1          2.4     2.7     1.7     1.4     1.4     1.0     2.0     1.0
# 2          3.5     3.8     3.8     3.8     3.8     4.0     3.8     3.5
# 3          3.0     1.4     2.7     1.0     2.0     3.3     2.4     1.0
# 4          3.8     3.8     3.5     3.5     3.5     2.7     3.8     3.5
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 566        3.8     4.0     3.8     3.8     3.8     3.8     4.0     3.8
# 567        3.3     2.4     3.5     3.0     3.8     3.8     4.0     4.0
# 568        2.7     3.0     3.3     3.0     3.5     3.8     3.3     3.0
# 569        2.4     1.0     1.0     3.0     2.7     3.0     2.7     2.0
# 570        2.4     1.7     3.3     1.4     3.3     1.7     3.0     1.4
#
#      EE-217  CS-212  CS-215   CGPA
# 0       3.8     1.0     1.7  2.205
# 1       2.7     2.0     1.0  2.008
# ...

# %%
year_3=student.loc[:,"MT-331":"CS-317"]
year_3
# Out:
#      MT-331  EF-303  HS-304  CS-301  CS-302  TC-383  MT-442  EL-332  CS-318  \
# 0       2.0     1.7     2.4     3.0     2.0     2.4     3.3     2.0     1.7
# 1       1.4     1.0     1.7     3.5     1.4     1.7     1.7     2.0     3.5
# 2       3.8     2.4     3.8     3.3     3.5     3.0     3.8     3.3     3.5
# 3       1.4     1.0     2.7     1.0     2.7     1.4     1.7     1.4     3.3
# 4       2.4     1.7     3.5     2.7     3.5     2.4     3.5     3.5     2.7
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 566     3.8     3.0     3.5     3.5     3.8     4.0     4.0     3.8     3.8
# 567     3.8     3.8     3.8     3.8     3.8     3.8     4.0     3.8     4.0
# 568     3.8     3.0     2.7     3.3     3.3     3.8     3.3     3.0     2.4
# 569     2.4     1.0     2.0     2.0     2.4     1.7     1.7     1.0     2.7
# 570     2.0     1.0     0.0     1.0     1.0     2.0     3.5     0.0     1.7
#
#      CS-306  CS-312  CS-317
# ...

# %%
column_3=year_3.columns
column_3
# Out:
# Index(['MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383', 'MT-442',
#        'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317'],
#       dtype='object')

# %%
year_3["CGPA"]=student["CGPA"]
year_3
# Out:
#      MT-331  EF-303  HS-304  CS-301  CS-302  TC-383  MT-442  EL-332  CS-318  \
# 0       2.0     1.7     2.4     3.0     2.0     2.4     3.3     2.0     1.7
# 1       1.4     1.0     1.7     3.5     1.4     1.7     1.7     2.0     3.5
# 2       3.8     2.4     3.8     3.3     3.5     3.0     3.8     3.3     3.5
# 3       1.4     1.0     2.7     1.0     2.7     1.4     1.7     1.4     3.3
# 4       2.4     1.7     3.5     2.7     3.5     2.4     3.5     3.5     2.7
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 566     3.8     3.0     3.5     3.5     3.8     4.0     4.0     3.8     3.8
# 567     3.8     3.8     3.8     3.8     3.8     3.8     4.0     3.8     4.0
# 568     3.8     3.0     2.7     3.3     3.3     3.8     3.3     3.0     2.4
# 569     2.4     1.0     2.0     2.0     2.4     1.7     1.7     1.0     2.7
# 570     2.0     1.0     0.0     1.0     1.0     2.0     3.5     0.0     1.7
#
#      CS-306  CS-312  CS-317   CGPA
# ...

# %% [markdown]
# As you can see we divide the dataset in to 1 year , 2nd year and 3rd year

# %% [markdown]
# # now let's visiualize our datset

# %%
# %matplotlib inline
for i in column_1:
    plt.figure(figsize=(7,5))
    ax=sns.barplot(x=year_1[i],y=student["CGPA"],data=student,palette="YlOrRd")
    plt.show()

# %% [markdown]
#  In the Course of first year PH-121(physics),CY,CS,HS,EE,ME,MT many student had scored good almost A+ or 4 CGPA which is very good
# so we can see the easily only 22 student got that CGPA higher it means there grades in all subject are good as we can clesaly see CGPA of that students are also high

# %%
# %matplotlib inline
for i in column_2:
    plt.figure(figsize=(7,5))
    ax=sns.swarmplot(x=year_2[i],y=student["CGPA"],data=student,palette="YlOrRd")
    plt.show()

# %% [markdown]
# In the second year of university many students have sored 3.78 grade or ew can say  maximum students and very less students who scored 2.7 ,1.4, 4,1.7,0.0 and we cxan also see that in many subjects maximum students lie between 2.5 CGPA to 3.8 CGPA in second year maybe few students score 4 CGPA due to increase in toughness level odf the subject whn year increses

# %%
# %matplotlib inline
for i in column_3:
    plt.figure(figsize=(9,5))
    ax=sns.stripplot(x=year_3[i],y=student["CGPA"],data=student,palette="YlOrRd",s=6)
    plt.show()

# %%
plt.figure(figsize=(9,7))
ax=sns.swarmplot(x=year_1["MT-111"],y=year_2["MT-222"],data=student,palette="YlOrRd",s=5)
plt.show()

# %%
plt.figure(figsize=(15,7))
ax=sns.jointplot(x=year_1["PH-121"],y=year_1["MT-111"],hue="CGPA",data=student,palette="YlOrRd",s=10)
plt.show()

# %% [markdown]
# # let's do some preprocessing

# %% [markdown]
# In the third year we can clearly see that there are many students whoes CGPA lies between 3.5 to 4.0 and many students have CGPA
# 3.8 CGPA students

# %%
# let's plot for 1st year
plt.figure(figsize=(20,25))
column=1
for columns in year_1:
    if column <=10:
        plt.subplot(4,4,column)
        ax=sns.distplot(year_1[columns])
        plt.xlabel(columns,fontsize=15)
    column+=1
plt.show()

# %%
year_1.skew()
# Out:
# PH-121      -0.960324
# HS-101      -0.363115
# CY-105      -1.442548
# HS-105/12   -0.637353
# MT-111      -0.900828
# CS-105      -1.342916
# CS-106      -1.108355
# EL-102      -0.881606
# EE-119      -0.908008
# ME-107      -0.463556
# CS-107      -0.691980
# CGPA        -0.497203
# dtype: float64

# %%
# let's plot for 2nd year
plt.figure(figsize=(20,25))
column=1
for columns in year_2:
    if column <=6:
        plt.subplot(4,4,column)
        ax=sns.distplot(year_2[columns])
        plt.xlabel(columns,fontsize=15)
    column+=1
plt.show()

# %%
year_2.skew()
# Out:
# HS-205/20   -1.738435
# MT-222      -0.483424
# EE-222      -1.228535
# MT-224      -0.767567
# CS-210      -1.210150
# CS-211      -0.412646
# CS-203      -0.660174
# CS-214      -0.233041
# EE-217      -1.182826
# CS-212      -0.730195
# CS-215      -0.456341
# CGPA        -0.497203
# dtype: float64

# %% [markdown]
# NO skweness in the second year dataset

# %%
# let's plot for 2nd year
plt.figure(figsize=(20,25))
column=1
for columns in year_3:
    if column <=12:
        plt.subplot(4,4,column)
        ax=sns.distplot(year_3[columns])
        plt.xlabel(columns,fontsize=15)
    column+=1
plt.show()

# %%
year_3.skew()
# Out:
# MT-331   -1.031021
# EF-303   -0.496606
# HS-304   -0.971748
# CS-301   -0.786759
# CS-302   -1.176889
# TC-383   -0.610688
# MT-442   -1.340061
# EL-332   -0.970918
# CS-318   -0.762111
# CS-306   -0.915702
# CS-312   -0.543580
# CS-317   -0.590224
# CGPA     -0.497203
# dtype: float64

# %% [markdown]
# As we can there is no skweness in the 3rd Dataset

# %%
corr=student.corr()
corr
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.412223  0.633643   0.544562  0.493515  0.665607
# HS-101     0.412223  1.000000  0.357065   0.485183  0.450547  0.443043
# CY-105     0.633643  0.357065  1.000000   0.587160  0.576516  0.611167
# HS-105/12  0.544562  0.485183  0.587160   1.000000  0.529589  0.526883
# MT-111     0.493515  0.450547  0.576516   0.529589  1.000000  0.435441
# CS-105     0.665607  0.443043  0.611167   0.526883  0.435441  1.000000
# CS-106     0.287623  0.349824  0.397915   0.514996  0.535008  0.291459
# EL-102     0.429056  0.371904  0.481646   0.380462  0.571040  0.365365
# EE-119     0.656458  0.317888  0.540344   0.464032  0.443726  0.588961
# ME-107     0.559502  0.356225  0.467592   0.383392  0.490401  0.487454
# CS-107     0.506954  0.496807  0.514901   0.565709  0.515207  0.528688
# HS-205/20  0.323948  0.194540  0.324784   0.228998  0.349651  0.212193
# ...

# %%
plt.figure(figsize=(15,14))
sns.heatmap(corr,annot=True,annot_kws={'size':8},linewidths=2,linecolor="black",square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can clearly see that CS-317 have strong correlation with CGPA

# %%
student.skew()
# Out:
# PH-121      -0.960324
# HS-101      -0.363115
# CY-105      -1.442548
# HS-105/12   -0.637353
# MT-111      -0.900828
# CS-105      -1.342916
# CS-106      -1.108355
# EL-102      -0.881606
# EE-119      -0.908008
# ME-107      -0.463556
# CS-107      -0.691980
# HS-205/20   -1.738435
# MT-222      -0.483424
# EE-222      -1.228535
# MT-224      -0.767567
# CS-210      -1.210150
# CS-211      -0.412646
# CS-203      -0.660174
# CS-214      -0.233041
# EE-217      -1.182826
# CS-212      -0.730195
# CS-215      -0.456341
# MT-331      -1.031021
# EF-303      -0.496606
# HS-304      -0.971748
# CS-301      -0.786759
# CS-302      -1.176889
# TC-383      -0.610688
# MT-442      -1.340061
# EL-332      -0.970918
# CS-318      -0.762111
# CS-306      -0.915702
# CS-312      -0.543580
# CS-317      -0.590224
# CS-403      -0.880424
# CS-421      -0.741111
# CS-406      -2.291775
# CS-414      -2.348161
# CS-419      -1.085171
# CS-423      -1.046928
# CS-412      -2.348138
# ...

# %% [markdown]
# As we can see therer is no skweness in the dataset

# %% [markdown]
# # let's build our Model 1

# %%
#let;s seprate our model target and label variable
x=year_1.drop(columns="CGPA")
y=year_1["CGPA"]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[0.675     , 0.35      , 0.425     , ..., 0.62857143, 0.425     ,
#         0.425     ],
#        [0.95      , 0.25      , 0.35      , ..., 0.25714286, 0.25      ,
#         0.825     ],
#        [0.95      , 0.75      , 0.95      , ..., 0.85714286, 0.875     ,
#         0.675     ],
#        ...,
#        [0.75      , 0.95      , 0.875     , ..., 0.94285714, 0.75      ,
#         1.        ],
#        [0.95      , 0.825     , 0.25      , ..., 0.62857143, 0.425     ,
#         1.        ],
#        [0.5       , 0.25      , 0.25      , ..., 0.42857143, 0.35      ,
#         0.675     ]])

# %%
# now lets's check VIF values to find the mullticollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data['VIF'] = [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]
vif_data["faeture"]=x.columns
print(vif_data)
# Out:
#           VIF    faeture
# 0   30.582079     PH-121
# 1   15.529560     HS-101
# 2   33.813062     CY-105
# 3   21.187442  HS-105/12
# 4   28.110836     MT-111
# 5   23.386590     CS-105
# 6   20.576266     CS-106
# 7   19.579297     EL-102
# 8   25.417456     EE-119
# 9   16.599362     ME-107
# 10  19.889941     CS-107

# %% [markdown]
# # Let's build model for 1st year

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn import svm

# %% [markdown]
# # Linear regression

# %%
def select_best_random_state(x_scaled, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,200):
        X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.3, random_state=random_state)
        LR = LinearRegression()
        LR.fit(X_train, y_train)
        y_pred = LR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score

best_random_state, best_r2_score= select_best_random_state(x_scaled, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 133
# Best r2_score:-  88.22726439445297

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.3, random_state=133)
LR=LinearRegression()
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
y_pred_train=LR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 81.48147053114876
# mean_squared_error 0.04807167873747248
# men absolute eroor 0.16812388611462536
# mean_squared_error 0.21925254556668772

# %% [markdown]
# # RandomForest Regression

# %%
def select_best_random_state(x_scaled, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=random_state)
        RFR=RandomForestRegressor()
        RFR.fit(X_train, y_train)
        y_pred = RFR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x_scaled, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 168
# Best r2_score:-  89.3745763665204

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=168)
RFR=RandomForestRegressor()
RFR.fit(X_train, y_train)
y_pred = RFR.predict(X_test)
y_pred_train=RFR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 97.24201015418905
# mean_squared_error 0.03721889261130432
# men absolute eroor 0.15450478260869568
# mean_squared_error 0.19292198581629913

# %% [markdown]
# # DecisionTreeRegressor

# %%
def select_best_random_state(x_scaled, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=random_state)
        DTR=DecisionTreeRegressor()
        DTR.fit(X_train, y_train)
        y_pred = DTR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state
            

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x_scaled, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 221
# Best r2_score:-  79.71408133596218

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=221)
DTR=DecisionTreeRegressor()
DTR.fit(X_train, y_train)
y_pred = DTR.predict(X_test)
y_pred_train=DTR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 100.0
# mean_squared_error 0.09246467826086957
# men absolute eroor 0.2386434782608695
# mean_squared_error 0.3040800523889549

# %% [markdown]
# # Gradient Bossting regressor

# %%
def select_best_random_state(x_scaled, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=random_state)
        GBR=GradientBoostingRegressor()
        GBR.fit(X_train, y_train)
        y_pred = GBR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x_scaled, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 45
# Best r2_score:-  89.6096012027777

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=45)
GBR=GradientBoostingRegressor()
GBR.fit(X_train, y_train)
y_pred = GBR.predict(X_test)
y_pred_train=GBR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 93.92541453084888
# mean_squared_error 0.038930485110926526
# men absolute eroor 0.15483321203402511
# mean_squared_error 0.19730809692186108

# %% [markdown]
# # Extra Tree regressor

# %%
def select_best_random_state(x_scaled, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=random_state)
        ETR = ExtraTreesRegressor()
        ETR.fit(X_train, y_train)
        y_pred = ETR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x_scaled, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 168
# Best r2_score:-  89.1383999817125

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=168)
ETR=ExtraTreesRegressor()
ETR.fit(X_train, y_train)
y_pred = ETR.predict(X_test)
y_pred_train=ETR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 100.0
# mean_squared_error 0.036606653120869546
# men absolute eroor 0.15643382608695655
# mean_squared_error 0.19132865211689948

# %% [markdown]
# # SVM

# %%
def select_best_random_state(x_scaled, y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=random_state)
        support=svm.SVR()
        support.fit(X_train, y_train)
        y_pred = support.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x_scaled, y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 118
# Best r2_score:-  90.28976880153682

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=118)
support=svm.SVR()
support.fit(X_train, y_train)
y_pred = support.predict(X_test)
y_pred_train=support.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 92.5570093645782
# mean_squared_error 0.03165297853671365
# men absolute eroor 0.14286971584350686
# mean_squared_error 0.17791283971853647

# %% [markdown]
# # Now after doing all this we will do cross validation to test that our model overfitting or no

# %%
from sklearn.model_selection import cross_val_score

# %%
cvr=cross_val_score(LR,x_scaled,y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.74486131 0.89875216 0.80811754 0.84931723 0.78630431 0.80746537
#  0.6781378 ]
# 0.7961365309647181
# differencve of r2_score and cross_val_score 7.306340779636145

# %%
cvr=cross_val_score(RFR,x_scaled,y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.67820019 0.90088707 0.80001552 0.8851157  0.7875323  0.79349232
#  0.71274278]
# 0.7939979816387656
# differencve of r2_score and cross_val_score 7.520195712231404

# %%
cvr=cross_val_score(DTR,x_scaled,y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.29949369 0.80408182 0.57302374 0.74257826 0.23783843 0.6200795
#  0.52002734]
# 0.5424461112169884
# differencve of r2_score and cross_val_score 32.67538275440912

# %%
cvr=cross_val_score(GBR,x_scaled,y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.70310957 0.90986238 0.78649456 0.90118416 0.78611864 0.81057267
#  0.72658354]
# 0.8034179314343932
# differencve of r2_score and cross_val_score 6.578200732668638

# %%
cvr=cross_val_score(ETR,x_scaled,y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.69277395 0.9026585  0.80313807 0.88915261 0.77862489 0.79014708
#  0.71101374]
# 0.7953584070278568
# differencve of r2_score and cross_val_score 7.384153173322283

# %%
cvr=cross_val_score(support,x_scaled,y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.7045787  0.88835772 0.81086063 0.85910976 0.83092854 0.80094117
#  0.71644805]
# 0.8016035103358083
# differencve of r2_score and cross_val_score 6.759642842527125

# %% [markdown]
# # From the above we can see that GBR having less differnce so GBR is our best model

# %% [markdown]
# # Hyperparameter tunning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params= {
    'n_estimators': [100,150],  # List of values to try for n_estimators
    'learning_rate': [0.1,0.2],
    'max_depth': [3,4,5],
    'min_samples_split': [2,3,4],
    'min_samples_leaf': [1,2,3],
    'loss': ['ls']
}

# %%
GSCV=GridSearchCV(GradientBoostingRegressor(),params,cv=7)

# %%
GSCV.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.1, 0.2], 'loss': ['ls'],
#                          'max_depth': [3, 4, 5], 'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [100, 150]})

# %%
GSCV.best_params_
# Out:
# {'learning_rate': 0.1,
#  'loss': 'ls',
#  'max_depth': 3,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'n_estimators': 100}

# %%
Student_score_year1_model=GradientBoostingRegressor(n_estimators=100,max_depth=3,min_samples_leaf=1,loss="ls",learning_rate=0.1,min_samples_split=4)

# %%
Student_score_year1_model.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(loss='ls', min_samples_split=4)

# %%
pred=Student_score_year1_model.predict(X_test)

# %%
print("r2_score",r2_score(y_test,pred))
print("mean_squared_error",mean_squared_error(y_test,pred))
print("mean_absolute_error",mean_absolute_error(y_test,pred))
print("root_mean_squared_error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2_score 0.8752885332618164
# mean_squared_error 0.05092350465334674
# mean_absolute_error 0.17140730251925673
# root_mean_squared_error 0.22566236871340942

# %%
import pickle
project_name="Student_score_year1.pkl"
pickle.dump(Student_score_year1_model,open(project_name,'wb'))

# %%
import pickle
load_final_model=pickle.load(open('Student_score_year1.pkl','rb'))
final_result=load_final_model.score(X_test,y_test)
print(final_result*100)
# Out:
# 87.52885332618165

# %%
target_variable_prediction=pd.DataFrame([load_final_model.predict(X_test)[:],y_test[:]],index=["predicted","original"])
target_variable_prediction
# Out:
#                 0         1         2         3         4         5    \
# predicted  2.540877  3.375926  2.139528  2.790119  3.233292  2.452512
# original   2.294000  3.254000  2.128000  2.701000  2.984000  2.350000
#
#                 6         7         8        9         10        11   \
# predicted  3.872293  2.618575  2.968479  1.92561  2.702282  3.782023
# original   3.876000  2.793000  3.189000  2.08400  2.370000  3.806000
#
#                 12        13        14        15        16        17   \
# predicted  3.233469  2.409518  2.410346  2.844636  3.317844  2.665463
# original   3.332000  1.863000  1.989000  2.931000  3.523000  2.763000
#
#                18        19        20        21        22        23   \
# predicted  2.85105  1.973313  2.836368  2.427732  2.828407  2.825184
# original   2.68700  1.768000  3.136000  2.525000  2.938000  3.017000
#
#                 24        25        26        27        28        29   \
# ...

# %% [markdown]
# # Let's build model fro 2nd year

# %%
#let;s seprate our model target and label variable
x2=year_2.drop(columns="CGPA")
y2=year_2["CGPA"]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled2=scaler.fit_transform(x2)
x_scaled2
# Out:
# array([[0.825     , 0.25      , 0.875     , ..., 0.95      , 0.14285714,
#         0.425     ],
#        [0.6       , 0.675     , 0.425     , ..., 0.675     , 0.42857143,
#         0.25      ],
#        [0.875     , 0.95      , 0.95      , ..., 0.95      , 0.85714286,
#         0.95      ],
#        ...,
#        [0.675     , 0.75      , 0.825     , ..., 0.95      , 0.8       ,
#         0.75      ],
#        [0.6       , 0.25      , 0.25      , ..., 0.675     , 0.25714286,
#         0.35      ],
#        [0.6       , 0.425     , 0.825     , ..., 0.425     , 0.42857143,
#         0.35      ]])

# %% [markdown]
# # Linear regression

# %%
def select_best_random_state(x_scaled2, y2):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,200):
        X_train, X_test, y_train, y_test = train_test_split(x_scaled2, y2, test_size=0.3, random_state=random_state)
        LR = LinearRegression()
        LR.fit(X_train, y_train)
        y_pred = LR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score

best_random_state, best_r2_score= select_best_random_state(x_scaled2, y2)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 20
# Best r2_score:-  90.89092737175105

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled2, y2, test_size=0.3, random_state=20)
LR=LinearRegression()
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
y_pred_train=LR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 78.69893491487453
# mean_squared_error 0.03875108184191407
# men absolute eroor 0.15247439231343754
# mean_squared_error 0.19685294471232598

# %% [markdown]
# # GradientBoostingRegressor

# %%
def select_best_random_state(x_scaled2, y2):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x_scaled2, y2, test_size=0.2, random_state=random_state)
        GBR=GradientBoostingRegressor()
        GBR.fit(X_train, y_train)
        y_pred = GBR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x_scaled2, y2)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 230
# Best r2_score:-  91.82995867837546

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled2, y2, test_size=0.2, random_state=230)
GBR=GradientBoostingRegressor()
GBR.fit(X_train, y_train)
y_pred = GBR.predict(X_test)
y_pred_train=GBR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 93.06726122667759
# mean_squared_error 0.03180583780516665
# men absolute eroor 0.13420008203676936
# mean_squared_error 0.178341912643009

# %% [markdown]
# # DecisionTreeRegressor

# %%
def select_best_random_state(x_scaled2, y2):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x_scaled2, y2, test_size=0.2, random_state=random_state)
        DTR=DecisionTreeRegressor()
        DTR.fit(X_train, y_train)
        y_pred = DTR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state
            

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x_scaled2, y2)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 222
# Best r2_score:-  84.2884221739954

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled2, y2, test_size=0.2, random_state=222)
DTR=DecisionTreeRegressor()
DTR.fit(X_train, y_train)
y_pred = DTR.predict(X_test)
y_pred_train=DTR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 97.85778701875707
# mean_squared_error 0.06153940000000001
# men absolute eroor 0.19621739130434787
# mean_squared_error 0.24807136070090802

# %% [markdown]
# # Random forest regressor

# %%
def select_best_random_state(x_scaled2, y2):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x_scaled2, y2, test_size=0.2, random_state=random_state)
        RFR=RandomForestRegressor()
        RFR.fit(X_train, y_train)
        y_pred = RFR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x_scaled2, y2)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 208
# Best r2_score:-  92.15079041588217

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled2, y2, test_size=0.2, random_state=208)
RFR=RandomForestRegressor()
RFR.fit(X_train, y_train)
y_pred = RFR.predict(X_test)
y_pred_train=RFR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 95.87396384502149
# mean_squared_error 0.028794837733188
# men absolute eroor 0.13216235576259486
# mean_squared_error 0.1696904173286989

# %% [markdown]
# # Extra tree Regressor

# %%
def select_best_random_state(x_scaled2, y2):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(x_scaled2, y2, test_size=0.2, random_state=random_state)
        ETR = ExtraTreesRegressor()
        ETR.fit(X_train, y_train)
        y_pred = ETR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(x_scaled2, y2)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 208
# Best r2_score:-  92.78968265124222

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled2, y2, test_size=0.2, random_state=208)
ETR=ExtraTreesRegressor()
ETR.fit(X_train, y_train)
y_pred = ETR.predict(X_test)
y_pred_train=ETR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 97.92566644016686
# mean_squared_error 0.02854788769913034
# men absolute eroor 0.13387982608695628
# mean_squared_error 0.16896120175688364

# %%
from sklearn.model_selection import cross_val_score

# %%
cvr=cross_val_score(LR,x_scaled2,y2,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.72537404 0.79513738 0.86656217 0.88511915 0.8919427  0.88019731
#  0.62890557]
# 0.8104626168634577
# differencve of r2_score and cross_val_score 10.5052169356879

# %%
cvr=cross_val_score(RFR,x_scaled2,y2,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.85144694 0.8105361  0.9004394  0.86300867 0.85418427 0.7871436
#  0.7781933 ]
# 0.834993183106582
# differencve of r2_score and cross_val_score 8.052160311375467

# %%
cvr=cross_val_score(GBR,x_scaled2,y2,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.82187943 0.85457149 0.90169925 0.87910534 0.85450287 0.82845566
#  0.738987  ]
# 0.8398858650967119
# differencve of r2_score and cross_val_score 7.562892112362474

# %%
cvr=cross_val_score(DTR,x_scaled2,y2,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.6443157  0.61693532 0.80618801 0.75451932 0.50710825 0.61240835
#  0.60182487]
# 0.6490428304692557
# differencve of r2_score and cross_val_score 26.647195575108096

# %%
cvr=cross_val_score(ETR,x_scaled2,y2,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.85569724 0.78887783 0.90161096 0.87162459 0.8523506  0.87446204
#  0.79325544]
# 0.8482683856250831
# differencve of r2_score and cross_val_score 6.724640059525355

# %% [markdown]
# # As you can see the least score is for extra tree classfier

# %% [markdown]
# # Hyperparameter tunning

# %%
params= {
    'n_estimators': [100,150],  # List of values to try for n_estimators
    'max_features': ['sqrt','log2'],
    'max_depth': [3,4,5],
    'min_samples_split': [2,3,4],
    'min_samples_leaf': [1,2,3],
}

# %%
GSCV=GridSearchCV(ExtraTreesRegressor(),params,cv=7)

# %%
GSCV.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=ExtraTreesRegressor(),
#              param_grid={'max_depth': [3, 4, 5],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [100, 150]})

# %%
GSCV.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 'log2',
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'n_estimators': 150}

# %%
Student_score_year2_model=GradientBoostingRegressor(n_estimators=150,max_depth=5,min_samples_leaf=1,max_features="log2",min_samples_split=4)

# %%
Student_score_year2_model.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, max_features='log2', min_samples_split=4,
#                           n_estimators=150)

# %%
pred=Student_score_year2_model.predict(X_test)

# %%
print("r2_score",r2_score(y_test,pred))
print("mean_squared_error",mean_squared_error(y_test,pred))
print("mean_absolute_error",mean_absolute_error(y_test,pred))
print("root_mean_squared_error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2_score 0.911432185457711
# mean_squared_error 0.032978027339522736
# mean_absolute_error 0.14213308864035376
# root_mean_squared_error 0.1815985334178741

# %%
import pickle
project_name="Student_score_year2.pkl"
pickle.dump(Student_score_year2_model,open(project_name,'wb'))

# %%
import pickle
load_final_model2=pickle.load(open('Student_score_year2.pkl','rb'))
final_result=load_final_model.score(X_test,y_test)
print(final_result*100)
# Out:
# 91.1432185457711

# %%
target_variable_prediction=pd.DataFrame([load_final_model2.predict(X_test)[:],y_test[:]],index=["predicted","original"])
target_variable_prediction
# Out:
#                 0         1        2         3         4         5    \
# predicted  2.974531  3.027815  2.51711  1.710256  2.462297  2.099033
# original   3.043000  3.335000  2.75000  1.763000  2.644000  2.084000
#
#                 6         7         8         9         10        11   \
# predicted  1.968056  2.702301  2.864785  3.421092  2.293886  2.730833
# original   1.658000  2.701000  2.756000  3.254000  2.034000  2.756000
#
#                 12        13        14        15        16        17   \
# predicted  2.770617  3.371752  2.534393  2.867543  2.953791  1.536421
# original   2.956000  3.247000  2.266000  2.895000  3.042000  1.261000
#
#                 18        19        20        21        22        23   \
# predicted  3.171479  2.803616  3.711565  2.398888  3.255044  2.962371
# original   3.179000  2.505000  3.424000  2.631000  3.229000  3.332000
#
#                 24        25        26        27        28        29   \
# ...

# %%
student
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0       2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7
# 1       3.8     1.0     1.4        1.0     2.7     2.0     1.0     3.8
# 2       3.8     3.0     3.8        2.7     3.3     3.8     2.7     3.3
# 3       1.0     2.4     1.4        1.0     1.0     3.5     1.4     1.7
# 4       3.5     3.5     3.5        3.3     3.8     3.8     3.5     3.3
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566     3.0     3.8     3.8        3.5     4.0     3.8     3.5     3.5
# 567     4.0     3.8     3.8        3.8     3.8     3.8     3.8     3.5
# 568     3.0     3.8     3.5        3.3     3.8     3.8     3.8     3.8
# 569     3.8     3.3     1.0        3.8     1.0     1.4     2.7     1.7
# 570     2.0     1.0     1.0        2.0     2.0     1.4     3.0     2.4
#
#      EE-119  ME-107  CS-107  HS-205/20  MT-222  EE-222  MT-224  CS-210  \
# ...

# %%
student["CGPA"].value_counts()
# Out:
# 3.019    5
# 3.058    3
# 2.793    3
# 3.443    3
# 2.206    3
#         ..
# 2.555    1
# 2.042    1
# 2.634    1
# 2.053    1
# 1.753    1
# Name: CGPA, Length: 491, dtype: int64

# %%
student.skew()
# Out:
# PH-121      -0.960324
# HS-101      -0.363115
# CY-105      -1.442548
# HS-105/12   -0.637353
# MT-111      -0.900828
# CS-105      -1.342916
# CS-106      -1.108355
# EL-102      -0.881606
# EE-119      -0.908008
# ME-107      -0.463556
# CS-107      -0.691980
# HS-205/20   -1.738435
# MT-222      -0.483424
# EE-222      -1.228535
# MT-224      -0.767567
# CS-210      -1.210150
# CS-211      -0.412646
# CS-203      -0.660174
# CS-214      -0.233041
# EE-217      -1.182826
# CS-212      -0.730195
# CS-215      -0.456341
# MT-331      -1.031021
# EF-303      -0.496606
# HS-304      -0.971748
# CS-301      -0.786759
# CS-302      -1.176889
# TC-383      -0.610688
# MT-442      -1.340061
# EL-332      -0.970918
# CS-318      -0.762111
# CS-306      -0.915702
# CS-312      -0.543580
# CS-317      -0.590224
# CS-403      -0.880424
# CS-421      -0.741111
# CS-406      -2.291775
# CS-414      -2.348161
# CS-419      -1.085171
# CS-423      -1.046928
# CS-412      -2.348138
# ...

# %%
#let;s seprate our model target and label variable
final_x=student.drop(columns="CGPA")
final_y=student["CGPA"]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
final_scaled_x=scaler.fit_transform(final_x)
final_scaled_x
# Out:
# array([[0.675, 0.35 , 0.425, ..., 0.425, 0.75 , 0.875],
#        [0.95 , 0.25 , 0.35 , ..., 0.5  , 0.5  , 0.75 ],
#        [0.95 , 0.75 , 0.95 , ..., 0.95 , 0.875, 0.95 ],
#        ...,
#        [0.75 , 0.95 , 0.875, ..., 0.825, 0.875, 0.875],
#        [0.95 , 0.825, 0.25 , ..., 0.75 , 0.675, 0.5  ],
#        [0.5  , 0.25 , 0.25 , ..., 0.825, 0.25 , 0.425]])

# %% [markdown]
# # Linear regression

# %%
def select_best_random_state(final_scaled_x, final_y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,200):
        X_train, X_test, y_train, y_test = train_test_split(final_scaled_x, final_y, test_size=0.3, random_state=random_state)
        LR = LinearRegression()
        LR.fit(X_train, y_train)
        y_pred = LR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score

best_random_state, best_r2_score= select_best_random_state(final_scaled_x, final_y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 59
# Best r2_score:-  96.93809971555673

# %%
X_train, X_test, y_train, y_test = train_test_split(final_scaled_x, final_y, test_size=0.2, random_state=59)
LR=LinearRegression()
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
y_pred_train=LR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 94.11451477522381
# mean_squared_error 0.01064683787467211
# men absolute eroor 0.078022111933098
# mean_squared_error 0.10318351551809092

# %% [markdown]
# # RandomForest Regression

# %%
def select_best_random_state(final_scaled_x, final_y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(final_scaled_x, final_y, test_size=0.2, random_state=random_state)
        RFR=RandomForestRegressor()
        RFR.fit(X_train, y_train)
        y_pred = RFR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(final_scaled_x, final_y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 261
# Best r2_score:-  96.94608869238223

# %%
X_train, X_test, y_train, y_test = train_test_split(final_scaled_x, final_y, test_size=0.2, random_state=261)
RFR=RandomForestRegressor()
RFR.fit(X_train, y_train)
y_pred = RFR.predict(X_test)
y_pred_train=RFR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 99.11786629542223
# mean_squared_error 0.011515850791304323
# men absolute eroor 0.08623026086956517
# mean_squared_error 0.1073119321944411

# %% [markdown]
# # Gradient boost regressor

# %%
def select_best_random_state(final_scaled_x, final_y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(final_scaled_x, final_y, test_size=0.2, random_state=random_state)
        GBR=GradientBoostingRegressor()
        GBR.fit(X_train, y_train)
        y_pred = GBR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(final_scaled_x, final_y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 186
# Best r2_score:-  97.69577675631349

# %%
X_train, X_test, y_train, y_test = train_test_split(final_scaled_x, final_y, test_size=0.2, random_state=186)
GBR=GradientBoostingRegressor()
GBR.fit(X_train, y_train)
y_pred = GBR.predict(X_test)
y_pred_train=GBR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 99.61048689586795
# mean_squared_error 0.00798857703332794
# men absolute eroor 0.06900033326256509
# mean_squared_error 0.08937883996409855

# %%
def select_best_random_state(final_scaled_x, final_y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(final_scaled_x, final_y, test_size=0.2, random_state=random_state)
        DTR=DecisionTreeRegressor()
        DTR.fit(X_train, y_train)
        y_pred = DTR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state
            

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(final_scaled_x, final_y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 286
# Best r2_score:-  91.29268429057012

# %%
X_train, X_test, y_train, y_test = train_test_split(final_scaled_x, final_y, test_size=0.2, random_state=286)
DTR=DecisionTreeRegressor()
DTR.fit(X_train, y_train)
y_pred = DTR.predict(X_test)
y_pred_train=DTR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 100.0
# mean_squared_error 0.07366474782608694
# men absolute eroor 0.16897391304347828
# mean_squared_error 0.27141250491841185

# %% [markdown]
# # Extra tree regressor

# %%
def select_best_random_state(final_scaled_x, final_y):
    best_random_state =0
    best_r2_score =0

    for random_state in range(1,300):
        X_train, X_test, y_train, y_test = train_test_split(final_scaled_x, final_y, test_size=0.2, random_state=random_state)
        ETR = ExtraTreesRegressor()
        ETR.fit(X_train, y_train)
        y_pred = ETR.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        if r2 > best_r2_score:
            best_r2_score = r2
            best_random_state = random_state

    return best_random_state, best_r2_score


best_random_state, best_r2_score= select_best_random_state(final_scaled_x, final_y)
print("Best Random State  :", best_random_state)
print("Best r2_score:- ",best_r2_score*100)
# Out:
# Best Random State  : 168
# Best r2_score:-  98.1487369293362

# %%
X_train, X_test, y_train, y_test = train_test_split(final_scaled_x, final_y, test_size=0.2, random_state=168)
ETR=ExtraTreesRegressor()
ETR.fit(X_train, y_train)
y_pred = ETR.predict(X_test)
y_pred_train=ETR.predict(X_train)
print("r2_score om training dataset",r2_score(y_train,y_pred_train)*100)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("men absolute eroor",mean_absolute_error(y_test,y_pred))
print("mean_squared_error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score om training dataset 100.0
# mean_squared_error 0.007187187622608691
# men absolute eroor 0.06749460869565219
# mean_squared_error 0.08477728246770294

# %% [markdown]
# # let's do cross validation to valkidate our model

# %%
cvr=cross_val_score(LR,final_scaled_x,final_y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.85181469 0.93960486 0.96575469 0.9267055  0.94159051 0.96201114
#  0.84055464]
# 0.9182908611192014
# differencve of r2_score and cross_val_score -8.955494204789039

# %%
cvr=cross_val_score(RFR,final_scaled_x,final_y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.84429241 0.94217135 0.94508178 0.9485892  0.90925649 0.93289595
#  0.83055054]
# 0.9075482459405094
# differencve of r2_score and cross_val_score -7.881232686919837

# %%
cvr=cross_val_score(DTR,final_scaled_x,final_y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.54291022 0.84933563 0.8175639  0.854455   0.65091356 0.84274654
#  0.70545049]
# 0.7519107625277999
# differencve of r2_score and cross_val_score 7.682515654351119

# %%
cvr=cross_val_score(GBR,final_scaled_x,final_y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.91081394 0.96756814 0.96399899 0.96008294 0.88931248 0.96215122
#  0.8449411 ]
# 0.928409830620098
# differencve of r2_score and cross_val_score -9.96739115487869

# %%
cvr=cross_val_score(ETR,final_scaled_x,final_y,cv=7)
print(cvr)
print(cvr.mean())
print("differencve of r2_score and cross_val_score",(r2_score(y_pred,y_test)-cvr.mean())*100)
# Out:
# [0.88387988 0.95232713 0.96953562 0.95294843 0.94102682 0.95880431
#  0.85282932]
# 0.9301930714527772
# differencve of r2_score and cross_val_score -10.145715238146613

# %% [markdown]
# # As you can see our best model is ETR let's do hyperparmater tunning

# %% [markdown]
# # Hyperparameter tunning

# %%
params= {
    'n_estimators': [100,150],  # List of values to try for n_estimators
    'max_features': ['sqrt','log2'],
    'max_depth': [3,4,5],
    'min_samples_split': [2,3,4],
    'min_samples_leaf': [1,2,3],
}

# %%
GSCV_final=GridSearchCV(ExtraTreesRegressor(),params,cv=7)

# %%
GSCV_final.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=ExtraTreesRegressor(),
#              param_grid={'max_depth': [3, 4, 5],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [100, 150]})

# %%
GSCV_final.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
Student_score_final_model=GradientBoostingRegressor(n_estimators=100,max_depth=5,min_samples_leaf=1,max_features="sqrt",min_samples_split=2)

# %%
Student_score_final_model.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, max_features='sqrt')

# %%
pred=Student_score_final_model.predict(X_test)

# %%
print("r2_score",r2_score(y_test,pred))
print("mean_squared_error",mean_squared_error(y_test,pred))
print("mean_absolute_error",mean_absolute_error(y_test,pred))
print("root_mean_squared_error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2_score 0.958201198983704
# mean_squared_error 0.016777191329549086
# mean_absolute_error 0.09573115988345886
# root_mean_squared_error 0.12952679772753237

# %%
import pickle
project_name="Student_final_score.pkl"
pickle.dump(Student_score_final_model,open(project_name,'wb'))

# %%
import pickle
load_final_score_model=pickle.load(open('Student_final_score.pkl','rb'))
final_result=load_final_score_model.score(X_test,y_test)
print(final_result*100)
# Out:
# 95.82011989837041

# %%
target_variable_prediction=pd.DataFrame([load_final_score_model.predict(X_test)[:],y_test[:]],index=["predicted","original"])
target_variable_prediction
# Out:
#                 0        1         2        3         4         5         6    \
# predicted  3.918246  2.58588  3.313533  3.19271  3.651992  3.040734  3.941545
# original   3.876000  2.58000  3.267000  3.18200  3.672000  2.984000  3.943000
#
#                 7         8         9         10        11        12   \
# predicted  2.830463  2.706811  3.654767  3.524258  3.385163  2.213023
# original   3.027000  2.779000  3.705000  3.618000  3.607000  2.264000
#
#                 13        14        15        16        17        18   \
# predicted  3.706911  1.929254  2.556909  2.563194  2.697539  2.431111
# original   3.759000  1.806000  2.396000  2.552000  2.619000  2.489000
#
#                 19        20        21        22        23        24   \
# predicted  3.126618  3.653394  3.345877  3.003089  3.628763  3.893938
# original   3.068000  3.625000  3.458000  3.063000  3.700000  3.876000
#
#                 25        26        27        28        29        30   \
# ...

# %% [markdown]
# # As you can see that our predicted model score is very close to what is original score with almost 95%
